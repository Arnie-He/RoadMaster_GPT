# %%
# !python main.py
# Out:
# Images shape: (26640, 32, 32)
# Labels shape: (26640, 43)
# X_train shape: (21312, 32, 32)
# y_train shape: (21312, 43)
# X_test shape: (5328, 32, 32)
# y_test shape: (5328, 43)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 32, 32, 1)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 6)         156
#
#  average_pooling2d (AverageP  (None, 14, 14, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  conv2d_2 (Conv2D)           (None, 1, 1, 120)         48120
#
#  dropout (Dropout)           (None, 1, 1, 120)         0
#
#  flatten (Flatten)           (None, 120)               0
#
#  dense (Dense)               (None, 120)               14520
#
#  dense_1 (Dense)             (None, 43)                5203
#
# =================================================================
# Total params: 70,415
# Trainable params: 70,415
# Non-trainable params: 0
# _________________________________________________________________
# 2023-05-07 08:47:33.194934: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# Epoch 1/25
# 666/666 [==============================] - 3s 4ms/step - loss: 2.1012 - accuracy: 0.4164 - val_loss: 0.9287 - val_accuracy: 0.7290
# Epoch 2/25
# 666/666 [==============================] - 2s 4ms/step - loss: 0.8382 - accuracy: 0.7474 - val_loss: 0.5379 - val_accuracy: 0.8472
# Epoch 3/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.5717 - accuracy: 0.8281 - val_loss: 0.3942 - val_accuracy: 0.8880
# Epoch 4/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.4475 - accuracy: 0.8619 - val_loss: 0.2900 - val_accuracy: 0.9212
# Epoch 5/25
# 666/666 [==============================] - 2s 4ms/step - loss: 0.3570 - accuracy: 0.8926 - val_loss: 0.2329 - val_accuracy: 0.9405
# Epoch 6/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.2943 - accuracy: 0.9114 - val_loss: 0.1967 - val_accuracy: 0.9459
# Epoch 7/25
# 666/666 [==============================] - 2s 4ms/step - loss: 0.2555 - accuracy: 0.9229 - val_loss: 0.1919 - val_accuracy: 0.9443
# Epoch 8/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.2201 - accuracy: 0.9324 - val_loss: 0.1544 - val_accuracy: 0.9583
# Epoch 9/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.1984 - accuracy: 0.9391 - val_loss: 0.1395 - val_accuracy: 0.9645
# Epoch 10/25
# 666/666 [==============================] - 2s 4ms/step - loss: 0.1781 - accuracy: 0.9468 - val_loss: 0.1224 - val_accuracy: 0.9668
# Epoch 11/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.1536 - accuracy: 0.9526 - val_loss: 0.1153 - val_accuracy: 0.9696
# Epoch 12/25
# 666/666 [==============================] - 2s 4ms/step - loss: 0.1410 - accuracy: 0.9564 - val_loss: 0.0890 - val_accuracy: 0.9782
# Epoch 13/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.1248 - accuracy: 0.9611 - val_loss: 0.1133 - val_accuracy: 0.9715
# Epoch 14/25
# 666/666 [==============================] - 4s 6ms/step - loss: 0.1170 - accuracy: 0.9625 - val_loss: 0.0922 - val_accuracy: 0.9771
# Epoch 15/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.1031 - accuracy: 0.9687 - val_loss: 0.0800 - val_accuracy: 0.9780
# Epoch 16/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.1007 - accuracy: 0.9675 - val_loss: 0.0876 - val_accuracy: 0.9792
# Epoch 17/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.0937 - accuracy: 0.9702 - val_loss: 0.0731 - val_accuracy: 0.9807
# Epoch 18/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.0924 - accuracy: 0.9709 - val_loss: 0.0827 - val_accuracy: 0.9794
# Epoch 19/25
# 666/666 [==============================] - 3s 5ms/step - loss: 0.0793 - accuracy: 0.9759 - val_loss: 0.0739 - val_accuracy: 0.9825
# Epoch 20/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.0795 - accuracy: 0.9751 - val_loss: 0.0743 - val_accuracy: 0.9820
# Epoch 21/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.0724 - accuracy: 0.9764 - val_loss: 0.0931 - val_accuracy: 0.9767
# Epoch 22/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.0652 - accuracy: 0.9796 - val_loss: 0.0735 - val_accuracy: 0.9839
# Epoch 23/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.0699 - accuracy: 0.9768 - val_loss: 0.0793 - val_accuracy: 0.9831
# Epoch 24/25
# 666/666 [==============================] - 3s 4ms/step - loss: 0.0635 - accuracy: 0.9797 - val_loss: 0.0788 - val_accuracy: 0.9805
# Epoch 25/25
# 666/666 [==============================] - 2s 4ms/step - loss: 0.0599 - accuracy: 0.9814 - val_loss: 0.0649 - val_accuracy: 0.9840
# 167/167 - 0s - loss: 0.0649 - accuracy: 0.9840 - 270ms/epoch - 2ms/step
#
# Valifdation accuracy: 0.9840465188026428
#
# Validation loss: 0.06493393331766129

# %%
from keras.models import load_model
from PIL import Image
import numpy as np
import cv2 as cv

model = load_model('model.h5')
image = cv.imread('/Users/kevin/Desktop/cs1470/RoadMaster_GPT/prompt/data/images/0.png')
image = cv.resize(image, (32, 32))
image = cv.cvtColor(image, cv.COLOR_BGR2GRAY)
image = np.array(image)
image = image/255
image = image.reshape(1, 32, 32, 1)
prediction = model.predict(image)
prediction_max = np.argmax(prediction)
print(prediction_max)
print(np.max(prediction))
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x15c63e200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 41ms/step
# 17
# 0.4920713
